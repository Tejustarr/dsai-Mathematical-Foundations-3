# %% [markdown]
# # Maxima & Minima classification with Hessian

# %%
import sympy as sp
x,y=sp.symbols('x y')
f=x**2+y**2
crit=sp.solve([sp.diff(f,x), sp.diff(f,y)],[x,y])
H=sp.hessian(f,(x,y))
crit,H
